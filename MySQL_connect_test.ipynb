# %%
import pymysql
# 開啟資料庫連線
db = pymysql.connect("chatbot_db","root","123456","" )
# 使用 cursor() 方法建立一個遊標物件 cursor
cursor = db.cursor()
# 使用 execute()  方法執行 SQL 查詢 
cursor.execute("SELECT VERSION()")
# 使用 fetchone() 方法獲取單條資料.
data = cursor.fetchone()
print ("Database version : %s " % data)
# 關閉資料庫連線
db.close()
# Out:
# Database version : 10.1.41-MariaDB-1~bionic

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

# 引入 MySQLdb 模組，提供連接 MySQL 的功能
import MySQLdb
import random

input_list = []
random.shuffle(input_list)
proutID = (i for i in input_list)
# 連接 MySQL 資料庫
db = MySQLdb.connect(host="chatbot_db",
    user="root", passwd="123456", db="")
cursor = db.cursor()

# 執行 MySQL 查詢指令
cursor.execute("SELECT col0 col1 col2 col3 col4 col5 FROM db_table where col0 IN "+proutID+";")

# 取回所有查詢結果
results = cursor.fetchall()

# 輸出結果
output_list = [i for i in results]
print (output_list)

# 關閉連線
db.close()

# %%
pip list
# Out:
# Package                  Version
# ------------------------ ---------
# alembic                  1.1.0
# asn1crypto               0.24.0
# async-generator          1.10
# attrs                    19.1.0
# backcall                 0.1.0
# bleach                   3.1.0
# blinker                  1.4
# certifi                  2019.6.16
# certipy                  0.1.3
# cffi                     1.12.3
# chardet                  3.0.4
# clarifai                 2.6.2
# Click                    7.0
# conda                    4.7.10
# conda-package-handling   1.4.0
# configparser             3.8.1
# cryptography             2.7
# decorator                4.4.0
# defusedxml               0.5.0
# entrypoints              0.3
# Flask                    0.12
# future                   0.18.1
# googleapis-common-protos 1.6.0
# grpcio                   1.24.3
# idna                     2.8
# ipykernel                5.1.2
# ipython                  7.8.0
# ipython-genutils         0.2.0
# ...
