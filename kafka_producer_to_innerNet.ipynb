# %%
from kafka import KafkaProducer
import sys, random, datetime, time, json

while True:
    if __name__ == "__main__":
        # 設定要連線到Kafka集群的相關設定, 並產生一個Kafka的Producer的實例
        producer1 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )

        producer2 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
#             key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )


        try:
            device_id = "001"
            t = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            temp = round(random.uniform(18, 30), 2)
            humidity = random.randint(0, 100)
            rd = random.random()
            tt = {"device_id": device_id, "timestamp": t, "Temperature": temp, 'rd': rd}
            hh = {"device_id": device_id, "timestamp": t, "bpm": humidity, 'rd': rd}

            print("Start sending messages ...")
            # 產生要發佈到Kafka的訊息
    #         producer1.send(topic="temperature", value=tt)
    #         producer2.send(topic="humidity", value=hh)
            # producer.send(topic=topicName, key=msgKey, value=msgValue)
            future1 = producer1.send(topic="temperature", value=tt)
            record_metadata1 = future1.get(timeout=10)
            print(record_metadata1)

            future2 = producer2.send(topic="bpm_test2", value=hh)
            record_metadata2 = future2.get(timeout=10)
            print(record_metadata2)
            print("Message sending completed!")

        except Exception as e:
            # 錯誤處理
            e_type, e_value, e_traceback = sys.exc_info()
            print("type ==> %s" % (e_type))
            print("value ==> %s" % (e_value))
            print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
            print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
            print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))


        finally:
            # 關掉Producer實例的連線
            producer1.close()
            producer2.close()
#             time.sleep(2)
# Out:
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1143, timestamp=1572936846065, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1046, timestamp=1572936846235, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1144, timestamp=1572936846467, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1047, timestamp=1572936846488, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1145, timestamp=1572936846727, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1048, timestamp=1572936846733, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1146, timestamp=1572936846966, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1049, timestamp=1572936846977, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1147, timestamp=1572936847207, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1050, timestamp=1572936847218, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1148, timestamp=1572936847452, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1051, timestamp=1572936847457, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1149, timestamp=1572936847674, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1052, timestamp=1572936847680, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1150, timestamp=1572936847902, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1053, timestamp=1572936847913, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1151, timestamp=1572936848160, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1054, timestamp=1572936848177, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1152, timestamp=1572936848431, checksum=None, serialized_key_size=-1, serialized_value_size=102, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1055, timestamp=1572936848442, checksum=None, serialized_key_size=-1, serialized_value_size=91, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1153, timestamp=1572936848678, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1056, timestamp=1572936848683, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1154, timestamp=1572936848925, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1057, timestamp=1572936848935, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1155, timestamp=1572936849235, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1058, timestamp=1572936849271, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1156, timestamp=1572936849516, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1059, timestamp=1572936849525, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1157, timestamp=1572936849824, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1060, timestamp=1572936849833, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1158, timestamp=1572936850100, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1061, timestamp=1572936850114, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1159, timestamp=1572936850369, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1062, timestamp=1572936850412, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1160, timestamp=1572936850738, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1063, timestamp=1572936850749, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1161, timestamp=1572936851000, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1064, timestamp=1572936851011, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1162, timestamp=1572936851255, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1065, timestamp=1572936851267, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1163, timestamp=1572936851518, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1066, timestamp=1572936851528, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1164, timestamp=1572936851779, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1067, timestamp=1572936851797, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1165, timestamp=1572936852046, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1068, timestamp=1572936852063, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1166, timestamp=1572936852310, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1069, timestamp=1572936852321, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1167, timestamp=1572936852562, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1070, timestamp=1572936853020, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1168, timestamp=1572936853273, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1071, timestamp=1572936853280, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1169, timestamp=1572936853520, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1072, timestamp=1572936853531, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1170, timestamp=1572936853825, checksum=None, serialized_key_size=-1, serialized_value_size=102, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1073, timestamp=1572936853833, checksum=None, serialized_key_size=-1, serialized_value_size=91, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1171, timestamp=1572936854056, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1074, timestamp=1572936854064, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1172, timestamp=1572936854291, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1075, timestamp=1572936854300, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1173, timestamp=1572936854534, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1076, timestamp=1572936854542, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1174, timestamp=1572936854817, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1077, timestamp=1572936854822, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1175, timestamp=1572936855039, checksum=None, serialized_key_size=-1, serialized_value_size=106, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1078, timestamp=1572936855044, checksum=None, serialized_key_size=-1, serialized_value_size=95, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1176, timestamp=1572936855310, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1079, timestamp=1572936855325, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1177, timestamp=1572936855571, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1080, timestamp=1572936855581, checksum=None, serialized_key_size=-1, serialized_value_size=91, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1178, timestamp=1572936855820, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1081, timestamp=1572936855832, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1179, timestamp=1572936856069, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1082, timestamp=1572936856078, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1180, timestamp=1572936856313, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1083, timestamp=1572936856322, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1181, timestamp=1572936856557, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1084, timestamp=1572936856568, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1182, timestamp=1572936856812, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1085, timestamp=1572936856822, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1183, timestamp=1572936857053, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1086, timestamp=1572936857061, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1184, timestamp=1572936857287, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1087, timestamp=1572936857295, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1185, timestamp=1572936857535, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1088, timestamp=1572936857546, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1186, timestamp=1572936857780, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1089, timestamp=1572936857788, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1187, timestamp=1572936858016, checksum=None, serialized_key_size=-1, serialized_value_size=106, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1090, timestamp=1572936858025, checksum=None, serialized_key_size=-1, serialized_value_size=95, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1188, timestamp=1572936858260, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1091, timestamp=1572936858268, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1189, timestamp=1572936858505, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=1092, timestamp=1572936858523, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-70e8f627a58e> in <module>
#      22             # 指定msgValue的序列化器
#      23             #value_serializer = str.encode,
# ---> 24             value_serializer = lambda m: json.dumps(m).encode('ascii'),
#      25         )
#      26
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     379         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     380                              wakeup_timeout_ms=self.config['max_block_ms'],
# --> 381                              **self.config)
#     382
#     383         # Get auto-discovered version from client if necessary
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in __init__(self, **configs)
#     238         if self.config['api_version'] is None:
#     239             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 240             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     241
#     242     def _can_bootstrap(self):
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     906             try:
#     907                 remaining = end - time.time()
# --> 908                 version = conn.check_version(timeout=remaining, strict=strict, topics=list(self.config['bootstrap_topics_filter']))
#     909                 if version >= (0, 10, 0):
#     910                     # cache the api versions map if it's available (starting
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/conn.py in check_version(self, timeout, strict, topics)
#    1173             f = self.send(request)
#    1174             # HACK: sleeping to wait for socket to send bytes
# -> 1175             time.sleep(0.1)
#    1176             # when broker receives an unrecognized request API
#    1177             # it abruptly closes our socket.
#
# KeyboardInterrupt:
